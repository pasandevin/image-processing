# %% [markdown]
# ## Images in Computer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Main Images Types
# ![image.png](attachment:image.png)

# %% [markdown]
# ## A Pixel
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2>1 Opencv Basics</h2>
# <h3>How to load a image</h3>

# %%
import cv2 #imporing thr opencv module

#img=cv2.imread('Samples/flower.jpg') #relative
img=cv2.imread(r'C:\Users\Migara Liyanage\Desktop\edXcope\Advaced Python Workshop\DAY 03\codes\Samples\flower.jpg') #absolute 

print(img[100,100])
print(img.shape)

img[100,:]=[0,255,255]

cv2.imshow('LIVE',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [ 26   0 255]
# (361, 480, 3)

# %%
import cv2 #imporing thr opencv module
from matplotlib import pyplot as plt
#img=cv2.imread('Samples/flower.jpg') #relative
img=cv2.imread(r'C:\Users\Migara Liyanage\Desktop\edXcope\Advaced Python Workshop\DAY 03\codes\Samples\flower.jpg') #absolute 

print(img[100,100])

plt.imshow(img)
#cv2.imshow('LIVE',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# [ 26   0 255]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img=cv2.imread('samples/flower.jpg')

img[100:150,100:200]=[0,0,255]

cv2.imshow('IMG',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Samples/lena512 -2.jpg',0)
cv2.imshow('LIVE',img)
plt.imshow(img,cmap='gray')
plt.colorbar()

# %% [markdown]
# <h3>Wrting and Saving Images</h3>
#
# <p>Use the function cv2.imwrite() to save an image.
#
# First argument is the file name, second argument is the image you want to save.</p>

# %%
img = cv2.imread('Samples/flower.jpg')
img[:,200]=[0,255,255]
cv2.imwrite('new-flower.png',img)
# Out:
# True

# %% [markdown]
# <h3>How to load a video file</h3>

# %%
source=cv2.VideoCapture('Samples/facevideo.mp4')
#0-webcam
#1,2,3=usb camera
#myVideo.mp4-file
#124.35.32.43.643 p/w user name - wifi camera

ret,img=source.read()
print(ret)
cv2.imshow('IMG',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# True

# %%
import cv2

source=cv2.VideoCapture(1)
#0-webcam
#1,2,3=usb camera
#myVideo.mp4-file
#124.35.32.43.643 p/w user name - wifi camera
while(True):
    
    ret,img=source.read()
    #print(ret)
    
    if(ret==False):
        break
    
    cv2.imshow('IMG',img)
    key=cv2.waitKey(10)
    
    if(key==27):
        break
    
cv2.destroyAllWindows()

# %% [markdown]
# cv2.waitKey() is a keyboard binding function. Its argument is the time in milliseconds. The function waits for specified milliseconds for any keyboard event. If you press any key in that time, the program continues. If 0 is passed, it waits indefinitely for a key stroke. It can also be set to detect specific key strokes like, if key a is pressed etc which we will discuss below.
#
# read more about ```cv2.waitKey()``` function
#
# 1. [Keyboard ASCII values](https://progtpoint.blogspot.com/2017/06/key-board-ascii-key-code.html)
# 2. [OpenCV official Documentation](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html#display-image)
